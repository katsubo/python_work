# %% [markdown]
# <a href="https://colab.research.google.com/github/katsubo/python_work/blob/main/python_programming_2nd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # colab 에서 배워보는 파이썬

# %% [markdown]
# <p><img alt="Colaboratory logo" height="45px" src="http://img.cuk.edu/university/main2/logo/logo_main_top_0101.png" align="left" hspace="10px" vspace="0px"></p>
# <p><h1>파이썬 프로그래밍 개발 환경 설정</h1></p>
#
# + <strong>Colab 환경의 특징</strong>
#     - 무료로 컴퓨팅 자원을 활용
#     - 쉽고 편리
#         * 컴퓨팅 파워를 쉽게 조절 가능
#     - 90분간 미사용시 세션이 끊어짐
#     - 최대 12시간 연속 사용 가능
#     - 여러사용자들과 동시에 사용가능
#
# + <strong>실습 순서</strong>
#   1. colab 둘러보기
#   1. 마크다운에 대하여 알아보기
#   1. 코드 입력창 설정하기
#   1. 코드 수행 및 결과 확인하기
#   1. 코드 저장하기
#   1. 코드 불러오기

# %% [markdown]
# # Colab 둘러보기

# %% [markdown]
# ##<strong>간단한 코드 수행해 보기</strong>
#
# 지금 읽고 계신 문서는 정적 웹페이지가 아니라 코드를 작성하고 실행할 수 있는 대화형 환경인 <strong>Colab 메모장</strong>입니다.
#
# 예를 들어 다음은 값을 계산하여 변수로 저장하고 결과를 출력하는 간단한 Python 스크립트가 포함된 <strong>코드 셀</strong>입니다.

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# ## 할당된 컴퓨팅 자원은 어떤것일까?

# %% [markdown]
# colab은 리눅스 운영체제에서 동작합니다.

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# 운영체제 확인하기

# %%
# !cat /etc/issue
# Out:
# Ubuntu 18.04.5 LTS \n \l

# %% [markdown]
# cpu 사양 확인해 보기

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2199.998
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4399.99
# clflush size	: 64
# ...

# %% [markdown]
# 메모리 사양 확인해 보기

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13302920 kB
# MemFree:        10515760 kB
# MemAvailable:   12309504 kB
# Buffers:          121412 kB
# Cached:          1793764 kB
# SwapCached:            0 kB
# Active:          1157536 kB
# Inactive:        1403840 kB
# Active(anon):     582464 kB
# Inactive(anon):      480 kB
# Active(file):     575072 kB
# Inactive(file):  1403360 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:              1268 kB
# Writeback:             0 kB
# AnonPages:        646316 kB
# Mapped:           231928 kB
# Shmem:              1172 kB
# KReclaimable:     113576 kB
# Slab:             155616 kB
# SReclaimable:     113576 kB
# SUnreclaim:        42040 kB
# KernelStack:        4960 kB
# PageTables:         8976 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6651460 kB
# Committed_AS:    3055280 kB
# VmallocTotal:   34359738367 kB
# ...

# %% [markdown]
# 디스크 사양 확인해 보기

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         108G   42G   66G  39% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.8G     0  5.8G   0% /dev/shm
# /dev/root       2.0G  1.2G  817M  59% /sbin/docker-init
# tmpfs           6.4G   28K  6.4G   1% /var/colab
# /dev/sda1        81G   46G   36G  57% /etc/hosts
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware

# %% [markdown]
# 파이썬 버전 확인하기

# %%
# !python --version
# Out:
# Python 3.7.12

# %% [markdown]
# ## 파이썬은 댜양한 라이브러리를 활용할 수 있다.

# %% [markdown]
# tensorflow가 설치 되어 있는지 확인해 보기

# %%
# !pip show tensorflow
# Out:
# Name: tensorflow
# Version: 2.8.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: grpcio, typing-extensions, opt-einsum, libclang, keras, flatbuffers, h5py, numpy, six, termcolor, tf-estimator-nightly, google-pasta, setuptools, protobuf, keras-preprocessing, tensorflow-io-gcs-filesystem, wrapt, tensorboard, astunparse, absl-py, gast
# Required-by: kapre

# %% [markdown]
# colab에서 제공되는 기본적이 라이브러리는 어떤 것이 있을까?

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ---------------------
# absl-py                       1.0.0
# alabaster                     0.7.12
# albumentations                0.1.12
# altair                        4.2.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arviz                         0.11.4
# astor                         0.8.1
# astropy                       4.3.1
# astunparse                    1.6.3
# atari-py                      0.2.9
# atomicwrites                  1.4.0
# attrs                         21.4.0
# audioread                     2.1.9
# autograd                      1.3
# Babel                         2.9.1
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bleach                        4.1.0
# blis                          0.4.1
# bokeh                         2.3.3
# Bottleneck                    1.3.4
# ...

# %% [markdown]
# zip 압축 라이브러리 설치해 보기
# With this you can extract all zip , tar ,tar.gz files which can further contain zip files just by instantiating the class and passing the argument of the path in the python module

# %%
pip install extract-zip

# %% [markdown]
# ## colab은 강력한 시각화를 제공한다

# %%
# %load_ext google.colab.data_table

# %%
from vega_datasets import data
data.cars()
# Out:
#                           Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0    chevrolet chevelle malibu              18.0          8         307.0
# 1            buick skylark 320              15.0          8         350.0
# 2           plymouth satellite              18.0          8         318.0
# 3                amc rebel sst              16.0          8         304.0
# 4                  ford torino              17.0          8         302.0
# ..                         ...               ...        ...           ...
# 401            ford mustang gl              27.0          4         140.0
# 402                  vw pickup              44.0          4          97.0
# 403              dodge rampage              32.0          4         135.0
# 404                ford ranger              28.0          4         120.0
# 405                 chevy s-10              31.0          4         119.0
#
#      Horsepower  Weight_in_lbs  Acceleration       Year  Origin
# ...

# %%
# %unload_ext google.colab.data_table

# %%
data.cars()
# Out:
#                           Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0    chevrolet chevelle malibu              18.0          8         307.0
# 1            buick skylark 320              15.0          8         350.0
# 2           plymouth satellite              18.0          8         318.0
# 3                amc rebel sst              16.0          8         304.0
# 4                  ford torino              17.0          8         302.0
# ..                         ...               ...        ...           ...
# 401            ford mustang gl              27.0          4         140.0
# 402                  vw pickup              44.0          4          97.0
# 403              dodge rampage              32.0          4         135.0
# 404                ford ranger              28.0          4         120.0
# 405                 chevy s-10              31.0          4         119.0
#
#      Horsepower  Weight_in_lbs  Acceleration       Year  Origin
# ...

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_bar().encode(
  x=alt.X('Miles_per_Gallon', bin=True),
  y='count()',
)
# Out:
# alt.Chart(...)

# %% [markdown]
# # 예제 코드 돌려보기

# %% [markdown]
# <strong>로또 자동 번호 추출 하기</strong>
# 출처 : https://wikidocs.net/1030

# %%
import random

num = int(input("lotto 게임 수를 입력하세요 : "))

# %%
# 입력한 게임 수 만큼 반복
for x in range(1, num+1):
    lotto = [0, 0, 0, 0, 0, 0]

    lotto[0] = random.randrange(1, 46, 1)

    lotto[1] = lotto[0]
    lotto[2] = lotto[0]
    lotto[3] = lotto[0]
    lotto[4] = lotto[0]
    lotto[5] = lotto[0]
        # 중복된 수가 발생되지 않도록 채번
    while (lotto[0] == lotto[1]):
        lotto[1] = random.randrange(1, 46, 1)
    while (lotto[0] == lotto[2] or lotto[1] == lotto[2]):
        lotto[2] = random.randrange(1, 46, 1)
    while (lotto[0] == lotto[3] or lotto[1] == lotto[3] or lotto[2] == lotto[3]):
        lotto[3] = random.randrange(1, 46, 1)
    while (lotto[0] == lotto[4] or lotto[1] == lotto[4] or lotto[2] == lotto[4] or lotto[3] == lotto[4]):
        lotto[4] = random.randrange(1, 46, 1)
    while (lotto[0] == lotto[5] or lotto[1] == lotto[5] or lotto[2] == lotto[5] or lotto[3] == lotto[5] or lotto[4] == lotto[5]):
        lotto[5] = random.randrange(1, 46, 1)
    # 결과를 정렬
    lotto.sort()

    # 결과 출력
    print(lotto)
